# %% [markdown]
#  # Python Operators

# %%
"""Operators are used to perform operations on variables and values."""

# %% [markdown]
# ### Arithmetic operators
# ### Assignment operators
# ### Comparison operators
# ### Logical operators
# ### Identity operators
# ### Membership operators
# ### Bitwise operators

# %% [markdown]
# ## Arithmetic operators(Arithmetic operators are used with numeric values to perform common mathematical operations:

# %%
a=int(input(" enter the number"))
b=int(input("enter the number"))

# %%
print(a+b )
# Out:
# 13

# %%
print(a-b )
# Out:
# 7

# %%
print(a*b )
# Out:
# 30

# %%
print(a/b ) #Division (returns quotient , a float)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1  #Division (returns quotient , a float)
# ----> 2 print(10/0)
#
# ZeroDivisionError: division by zero

# %%
print(a%b ) #returns reminder
# Out:
# 1

# %%
print(a//b ) #Floor division always returns an integer.It rounds DOWN to the nearest integer:
# Out:
# 3

# %%
print(a**2)

# %%
print(a//b)

# %%
print(5/2)

# %%
print(5//2)
# Out:
# 2

# %%
print(5%2)

# %% [markdown]
# # Python Assignment Operators

# %%
#Assignment operators are used to assign values to variables:
a=5
a=a+3
print(a)
# Out:
# 8

# %%
a+=3
print(a)
# Out:
# 11

# %%
a-=3
print(a)
# Out:
# 8

# %%
a*=3
print(a)

# %%
a/=3
print(a)

# %%
a%=3
print(a)

# %% [markdown]
# ## Python Comparison Operators

# %%
a=15
b=15
print(a>b)
# Out:
# False

# %%
print(a==b)
# Out:
# True

# %%
print(a!=b)
# Out:
# False

# %%
print(a>b)

# %%
print(a>=b)

# %%
print(a<=b)

# %%
a=67
b=67
print(a>=b)
