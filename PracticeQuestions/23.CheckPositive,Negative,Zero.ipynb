# %%
def check(num):
    match num:
        case _ if num > 0:
            print("Positive")
        case _ if num < 0:
            print("Negative")
        case _:
            print("Zero")

num = int(input("Enter the number: "))
check(num)
# Out:
# Positive

# %%
def check(num):
   if num>0:
    print("positive")
   elif num<0:
    print("negative")
   else:
    print("zero")   

num = int(input("Enter the number: "))
check(num)
# Out:
# negative
