# %%
def length_of_list(lst):
    l=0
    for i in lst:
        l+=1
    return l
l=list(map(int,input("enter the list elements seperated by comma").split(",")))   
print(length_of_list(l))
# Out:
# 3
