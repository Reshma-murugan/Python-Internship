# %%
D={"Reshma":98941,"Kowsalya":8300852,"Esther":123456,"Mauni":2314576,"uma":34567890,"indhu":87542549,"malar":987654322,"swetha":98765432,"muthu Selvi":98765432,"ashvitha":542345879}
x=input("enter the name")
while x!="quit":
    print(D[x])
    x=input("enter the name")
# Out:
# 98941
