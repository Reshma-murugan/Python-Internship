# %%
list = [10, 3.14, True, "hello", 25, False, 7.89, "python", 42, "java"]
list[2]=False # Replace value at index 2
list.pop() # Remove the last element
list.append(["hi","hello"]) #add one more list to that left
list.remove("hello") #remove based on value
print(list)
# Out:
# [10, 3.14, False, 25, False, 7.89, 'python', 42, ['hi', 'hello']]
