# %%
L = [1, 2, 3, 4, 3, 2, 1, 2, 5]
D = {}
for x in L:
    if x not in D:
        D[x] = 1   #This means:Create a key = 1  Store value = 1   
    else:
        D[x] += 1     

print(D)
# Out:
# {1: 2, 2: 3, 3: 2, 4: 1, 5: 1}
