# %% [markdown]
# Arithmetic operators are used with numeric values to perform common mathematical operations:

# %%
a=15
b=2
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 17
# 13
# 30
# 7.5
# 7
# 1
# 225
