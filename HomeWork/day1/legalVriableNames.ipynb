# %%
name="Reshma"
age=21
total_marks=50
_degree="BE"
department_name="CSE"
student_id=101

print(name)
print(age)
print(total_marks)
print(_degree)
print(department_name)
print(student_id)
# Out:
# Reshma
# 21
# 50
# BE
# CSE
# 101
