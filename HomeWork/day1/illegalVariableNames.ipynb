# %%
1name = "Reshma"     
total-marks = 50      
class = "A"           
student id = 101      
@dept = "CSE"
# Out:
#   Cell In[1], line 1
#     1name = "Reshma"
#     ^
# SyntaxError: invalid decimal literal
