# %%
list=["hi","hello"]
print(list.replace("hi","hii"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 list=["hi","hello"]
# ----> 2 print(list.replace("hi","hii"))
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
L=[1,1,"Hi",1.8,True]
L[0]="Python"
print(L[0])
# Out:
# Python

# %%
L=["Hi","2","Hello",75]
L[1]=36
L.remove("Hello")
L.append(86)
print(L)
# Out:
# ['Hi', 36, 75, 86]
