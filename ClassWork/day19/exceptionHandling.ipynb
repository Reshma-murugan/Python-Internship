# %%
try:
    a=10
    b=0
    print(a/b)
except:
    print("invalid b")
# Out:
# invalid b

# %%
try:
    a=20
    b="hkgu"
    print(a+d)
except Exception as e:
    print(e)
# Out:
# name 'd' is not defined

# %% [markdown]
# what is the reason for finally?

# %%
try:
    num = int(input("Enter a number: "))
    result = 10/num
    print("Result:",result)
except ValueError:
    print("Error: Invalid input")
except ZeroDivisionError:
    print("Error: Cannot divide by zero")
finally:
    print("program completed")
# Out:
# Error: Invalid input
# program completed

# %%
x=int(input("enter a value"))
for i in range(x):
    print(i,"+",x-i)
# Out:
# 0 + 10
# 1 + 9
# 2 + 8
# 3 + 7
# 4 + 6
# 5 + 5
# 6 + 4
# 7 + 3
# 8 + 2
# 9 + 1

# %%
def find_pair(x):
    for i in range(x//2+1):
       print(i,"+",x-i)
x=int(input("enter a value")) 
find_pair(x)
# Out:
# 0 + 13
# 1 + 12
# 2 + 11
# 3 + 10
# 4 + 9
# 5 + 8
# 6 + 7
