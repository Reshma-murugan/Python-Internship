# %%
k=1 
print(type(k))
# Out:
# <class 'int'>

# %%
k="Reshma"
print(type(k))
# Out:
# <class 'str'>

# %%
k=1.2
print(type(k))
# Out:
# <class 'float'>

# %%
k=True
print(type(k))
# Out:
# <class 'bool'>

# %%
k=1+2j
print(type(k))
# Out:
# <class 'complex'>

# %%
k=input('Enter your age')
print(type(k))
# Out:
# <class 'str'>

# %%
k=int(input("Enter your age:"))
print(type(k))
# Out:
# <class 'int'>
