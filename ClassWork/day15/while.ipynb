# %%
i=0
while i<=6:
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
i=50
while i>=30:
    print(i)
    i-=1
# Out:
# 50
# 49
# 48
# 47
# 46
# 45
# 44
# 43
# 42
# 41
# 40
# 39
# 38
# 37
# 36
# 35
# 34
# 33
# 32
# 31
# 30

# %%
k=[1,3,45,6,889,90]
for x in k:
    print(k.index(x),x)
# Out:
# 0 1
# 1 3
# 2 45
# 3 6
# 4 889
# 5 90

# %%
k=[1,3,45,6,889,90]
for x,y in enumerate(k):
    print(x,y)
# Out:
# 0 1
# 1 3
# 2 45
# 3 6
# 4 889
# 5 90

# %%
k=[1,3,45,6,889,90]
for i in range(len(k)):
    print(i,k[i])
# Out:
# 0 1
# 1 3
# 2 45
# 3 6
# 4 889
# 5 90

# %%
k=[1,3,45,6,889,90]
len=0
for x in k:
    len+=1
print(len)
# Out:
# 6

# %%
k=[1,3,45,6,889,90]
count=0
while

# %%
K=[1,3,45,6,889,90]
length=0
i=0
while [i:i+]
