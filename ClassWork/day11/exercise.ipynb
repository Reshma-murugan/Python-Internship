# %%
L=[1,2,3,4,5,6,7,8]
L[2:5]=["Hi"]
print(L)
# Out:
# [1, 2, 'Hi', 6, 7, 8]

# %%
D={1,2,3,4,5}
D.add(6)
print(D)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
new=(5,6,7,8)
new.remove(1)
print(new)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 new=(5,6,7,8)
# ----> 2 new.remove(1)
#       3 print(new)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
new=(5,6,7,8)
temp=list(new)
temp.remove(6)
new=tuple(temp)
print(new)
# Out:
# (5, 7, 8)

# %%
T={"hi":7,"hello":8}
T.update(hello=10)
print(T)
# Out:
# {'hi': 7, 'hello': 10}
